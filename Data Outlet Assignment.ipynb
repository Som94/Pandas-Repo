# %%
import pandas as pd

# %%
df=pd.read_csv('E:\Aroha Tech\Pandas Session\Data_Outlet.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
gfc=df.groupby('Item_Fat_Content')

# %%
gfc.first()
# Out:
#                  Item_Identifier  Item_Weight  Item_Visibility     Item_Type  \
# Item_Fat_Content
# LF                         FDM39         6.42         0.089499         Dairy
# Low Fat                    FDA15         9.30         0.016047         Dairy
# Regular                    DRC01         5.92         0.019278   Soft Drinks
# low fat                    DRJ59        11.65         0.019356   Hard Drinks
# reg                        FDN04        11.80         0.014087  Frozen Foods
#
#                   Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Fat_Content
# LF                178.1002            OUT010                       1998
# Low Fat           249.8092            OUT049                       1999
# Regular            48.2692            OUT018                       2009
# low fat            39.1164            OUT013                       1987
# reg               180.3344            OUT046                       1997
#
# ...

# %% [markdown]
# # Convert item fat content  intems into only Low Fat and Regular

# %%
convrt=df['Item_Fat_Content']

# %%
Item_Fat_Content_dup=[]

# %%
for i in convrt:
    if i[0].upper()=='L':
        i='Low Fat'
        #print(i)
        Item_Fat_Content_dup.append(i)
    else:
        i='Regular'
        #print(i)
        Item_Fat_Content_dup.append(i)

# %%
Item_Fat_Content_dup
# Out:
# ['Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
#  'Low Fat',
#  'Low Fat',
#  'Regular',
# ...

# %%
df['Item_Fat_Content']=Item_Fat_Content_dup

# %%
df.head(50)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
fc=df.groupby('Item_Fat_Content')

# %%
fc.first()
# Out:
#                  Item_Identifier  Item_Weight  Item_Visibility    Item_Type  \
# Item_Fat_Content
# Low Fat                    FDA15         9.30         0.016047        Dairy
# Regular                    DRC01         5.92         0.019278  Soft Drinks
#
#                   Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Fat_Content
# Low Fat           249.8092            OUT049                       1999
# Regular            48.2692            OUT018                       2009
#
#                  Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Fat_Content
# Low Fat               Medium               Tier 1  Supermarket Type1
# Regular               Medium               Tier 3  Supermarket Type2
#
#                   Item_Outlet_Sales
# Item_Fat_Content
# Low Fat                   3735.1380
# Regular                    443.4228

# %% [markdown]
# How Many Stores Open in perticular year

# %%
oey=df.groupby('Outlet_Establishment_Year')

# %%
oey.count()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Outlet_Establishment_Year
# 1985                                  1463            0              1463
# 1987                                   932          932               932
# 1997                                   930          930               930
# 1998                                   555          555               555
# 1999                                   930          930               930
# 2002                                   929          929               929
# 2004                                   930          930               930
# 2007                                   926          926               926
# 2009                                   928          928               928
#
#                            Item_Visibility  Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1985                                  1463       1463      1463
# ...

# %% [markdown]
# Rename Outlet Type

# %%
df.replace(to_replace=["Supermarket Type1","Supermarket Type2","Supermarket Type3"], value=["Type1","Type2","Type3"], inplace=True)

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# Percentage Calculation

# %%
iv=(df['Item_Visibility']/df['Item_Weight'])*100

# %%
iv
# Out:
# 0       0.172552
# 1       0.325646
# 2       0.095772
# 3       0.000000
# 4       0.000000
#           ...
# 8518    0.827143
# 8519    0.560650
# 8520    0.331946
# 8521    2.014156
# 8522    0.303232
# Length: 8523, dtype: float64

# %%
df['Item_Visibility']=iv

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.172552
# 1              DRC01        5.920          Regular         0.325646
# 2              FDN15       17.500          Low Fat         0.095772
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.827143
# 8519           FDS36        8.380          Regular         0.560650
# 8520           NCJ29       10.600          Low Fat         0.331946
# 8521           FDN46        7.210          Regular         2.014156
# 8522           DRG01       14.800          Low Fat         0.303232
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# Based on group most repeated Outlet_type value fill in Outlet_size

# %%
out_t=df.groupby(['Outlet_Type','Outlet_Size']).size()

# %%
out_t
# Out:
# Outlet_Type        Outlet_Size
# Grocery Store      Small           528
# Supermarket Type1  High            932
#                    Medium          930
#                    Small          1860
# Supermarket Type2  Medium          928
# Supermarket Type3  Medium          935
# dtype: int64

# %%
df['Outlet_Size'].fillna('Small')
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3        Small
# 4         High
#          ...
# 8518      High
# 8519     Small
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object
