# %%
import pandas as pd

# %%
df=pd.read_csv('E:\Aroha Tech\Pandas Session\Data_Outlet.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# When we want get some comparing results ,then we should go for filtering concept

# %%
people={'first':['Coery','Jane','John'],
      'last':['Schafer','Doe','Doe'],
       'email':['CoeryMSchafer@gmail.com','JaneDoe@gmail.com','JohnDoe@gmail.com']
     }

# %%
df1=pd.DataFrame(people)

# %%
df1
# Out:
#    first     last                    email
# 0  Coery  Schafer  CoeryMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@gmail.com
# 2   John      Doe        JohnDoe@gmail.com

# %% [markdown]
# Q. Get the records where last name is 'Doe'

# %%
df1['last']=='Doe'   # It will return Series object of boolean value in result set
                    # True are showing our matching filtering citeria result
                    # False are showing our unmatching filtering citeria result
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
# So, for getting exact/actual result , we apply to this into our data farme

# %%
df1[df1['last']=='Doe']
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
# We can get same result by storing Series object of boolean value into a variable

# %%
filt=df1['last']=='Doe'

# %%
df1[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
# There are another way to getting same result , so we have to pass those Series of boolean value inside loc[].(Can't use iloc )
# It is Faster than other
# And also we can get a specific column value aslo.

# %%
df1.loc[df1['last']=='Doe' ]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %%
# Or,

df1.loc[filt]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@gmail.com
# 2  John  Doe  JohnDoe@gmail.com

# %% [markdown]
# Q Display the email whose last name is Doe?

# %%
# If we want to get a specific column

# %%
df1.loc[filt,'email']      # Here is specific column is email
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# # And , Or oparetor in pandas

# %% [markdown]
# We can't use in pandas our python's and , or oparetor , instead of that we can use some special oparetors
#
# & ---> for and
#
# | ---> for or

# %%
# Q. Display the email id where first name is 'John' and last name is 'Doe'

# %%
filt=(df1['first']=='John') & (df1['last']=='Doe')   # When we use '&' or '|' , make sure we have to keep each part inside '()' ,
                                                    # Other wise we will get Type Error
df1.loc[filt,'email']
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# Q. Display the email id where first name is 'Coery' or last name is 'Doe'

# %%
filt=(df1['first']=='Coery') | (df1['last']=='Doe')

df1.loc[filt,'email']
# Out:
# 0    CoeryMSchafer@gmail.com
# 1          JaneDoe@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# Negative filter

# %%
# For negetive filter , just we add prefix '-' (minus) to Series object of boolean value.

# %%
# Q. Display the email id where first name is not 'John' or last name is not'Schafer'

# %%
filt=(df1['first']=='John') | (df1['last']=='Schafer')

# %%
df1.loc[filt,'email']     # This is not our acctual data according to th question.
# Out:
# 0    CoeryMSchafer@gmail.com
# 2          JohnDoe@gmail.com
# Name: email, dtype: object

# %%
# To get actual data according to question we have to add '-'' prefix to filt.

df1.loc[-filt,'email']
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %% [markdown]
# # # Work with huge data set

# %%
survey_df=pd.read_csv('E:\Aroha Tech\Pandas Session\Pandas\Developer Survey 2020\survey_results_public.csv', index_col='Respondent')

schema_df=pd.read_csv('E:\Aroha Tech\Pandas Session\Pandas\Developer Survey 2020\survey_results_schema.csv', index_col="Column")

# %%
survey_df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %% [markdown]
# # isin()

# %%
# It is a function which check given value is avialable or not, But we must pass list of values in isin(), 
# like, isin([<list of values>])

# %%
# Q. To check the country India is avialeble or not , if avialable then return

# %%
cont_filt=survey_df["Country"].isin(['India'])

# %%
survey_df.loc[cont_filt,'Country']
# Out:
# Respondent
# 7        India
# 22       India
# 58       India
# 63       India
# 149      India
#          ...
# 54757    India
# 55407    India
# 62464    India
# 62954    India
# 64236    India
# Name: Country, Length: 8403, dtype: object

# %% [markdown]
# # str.contains()

# %%
# If a string contaion the given string ,  then it will return whole string

# %%
str_filt=survey_df['UndergradMajor'].str.contains('statistics', na=False)   # na=False , bcz if there any nan value it not 
                                                                            # treated as string

# %%
survey_df.loc[str_filt,'UndergradMajor', ]
# Out:
# Respondent
# 10       Mathematics or statistics
# 12       Mathematics or statistics
# 55       Mathematics or statistics
# 72       Mathematics or statistics
# 131      Mathematics or statistics
#                    ...
# 34097    Mathematics or statistics
# 36284    Mathematics or statistics
# 42686    Mathematics or statistics
# 54068    Mathematics or statistics
# 58498    Mathematics or statistics
# Name: UndergradMajor, Length: 1849, dtype: object

# %%
survey_df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.loc['ConvertedComp']
# Out:
# QuestionText    Salary converted to annual USD salaries using ...
# Name: ConvertedComp, dtype: object

# %%
# Q. Display all the details which having more than 70000 salary

# %%
high_salary= survey_df['ConvertedComp'] > 70000

# %%
survey_df.loc[high_salary]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 8                              I am a developer by profession      Yes  36.0
# 16                             I am a developer by profession      Yes  45.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# 19                             I am a developer by profession       No  24.0
# ...                                                       ...      ...   ...
# 65586                          I am a developer by profession      Yes   NaN
# 65589                          I am a developer by profession      Yes   NaN
# 65602       I am not primarily a developer, but I write co...      Yes   NaN
# 65604                          I am a developer by profession       No   NaN
# 65617                          I am a developer by profession      Yes   NaN
#
# ...

# %%
# Q. Display country , main branch and What was your primary field of study(UndergradMajor) details 
#    which having more than 70000 salary

# %%
high_sal_filt=survey_df['ConvertedComp'] > 70000

# %%
survey_df.loc[high_sal_filt,['Country','MainBranch','ConvertedComp','UndergradMajor']]
# Out:
#                    Country                                         MainBranch  \
# Respondent
# 8            United States                     I am a developer by profession
# 16          United Kingdom                     I am a developer by profession
# 17           United States                     I am a developer by profession
# 18           United States                     I am a developer by profession
# 19           United States                     I am a developer by profession
# ...                    ...                                                ...
# 65586        United States                     I am a developer by profession
# 65589        United States                     I am a developer by profession
# 65602        United States  I am not primarily a developer, but I write co...
# 65604        United States                     I am a developer by profession
# 65617              Germany                     I am a developer by profession
#
# ...

# %%
# Q. Display country , main branch and What was your primary field of study(UndergradMajor) details
#    which having more than 70000 salary and the country should be in India, United state, united kingdom,Germany

# %%
countries=['India','United States','United Kingdom','Germany']

# %%
filtr=survey_df['Country'].isin(countries)

# %%
survey_df.loc[filtr,'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62464             India
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 28658, dtype: object

# %%
result_filt=(survey_df['ConvertedComp'] >70000) & (survey_df['Country'].isin(['India','United States','United Kingdom','Germany']))

# %%
survey_df.loc[result_filt,['Country','MainBranch','ConvertedComp','UndergradMajor']]
# Out:
#                    Country                                         MainBranch  \
# Respondent
# 8            United States                     I am a developer by profession
# 16          United Kingdom                     I am a developer by profession
# 17           United States                     I am a developer by profession
# 18           United States                     I am a developer by profession
# 19           United States                     I am a developer by profession
# ...                    ...                                                ...
# 65586        United States                     I am a developer by profession
# 65589        United States                     I am a developer by profession
# 65602        United States  I am not primarily a developer, but I write co...
# 65604        United States                     I am a developer by profession
# 65617              Germany                     I am a developer by profession
#
# ...
