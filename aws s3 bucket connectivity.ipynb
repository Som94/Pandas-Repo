# %%
import boto3,os

# %%
import pandas as pd

# %%
#client access creation

# %%
import boto3
s3_client=boto3.client('s3')

# %%
# Resource access creation

# %%
s3=boto3.resource('s3')

# %%
#creating a bucket

# %%
s3.create_bucket(Bucket='som-aws-bucket-2')
# Out:
# s3.Bucket(name='som-aws-bucket-2')

# %%
#To Show how many bucket in your s3

# %%
for bucket in s3.buckets.all():
    print(bucket)
# Out:
# s3.Bucket(name='som-aws-bucket-1')
# s3.Bucket(name='som-aws-bucket-2')

# %%
#To show all objects in all buckets

# %%
for bucket in s3.buckets.all():
    for obj in bucket.objects.all():
        print(obj)
        print('-------------------------')
        print(os.path.join(obj.bucket_name , obj.key))
# Out:
# s3.ObjectSummary(bucket_name='som-aws-bucket-1', key='Train.csv')
# -------------------------
# som-aws-bucket-1\Train.csv

# %%
#Access file from s3

# %%
objc=s3_client.get_object(Bucket='som-aws-bucket-1',Key='Train.csv')

# %%
#read that file

# %%
data=pd.read_csv(objc['Body'])

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
import pandas as pd
path='s3://som-aws-bucket-1/Train.csv'
df=pd.read_csv(path)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#upload file into bucket

# %%
s3.meta.client.upload_file('E:\Aroha Tech\Pandas Session\FILE.csv','som-aws-bucket-1','FILE.csv')

# %%
#Note if s3 was as client instead of of a resource, s3 command becames,
#-> s3.upload_file('<File Name>','<Bucket Name>','<Key Name which is nothing but your file name>')

# %%
#delete object(Nothing but a file )

# %%
s3.meta.client.delete_object(Bucket="som-aws-bucket-1",Key="Train.csv") # Bucket and Key name must be case sensetive
# Out:
# {'ResponseMetadata': {'RequestId': 'HWMZ8S8EK7WK90R7',
#   'HostId': 'bWK7ZIPK54Cqrp9686qI4s2Cxp2jURru0PqUITkZaf3UWVzjXUN2VpQWfPFJ/45rIrF0swyv3ZU=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'bWK7ZIPK54Cqrp9686qI4s2Cxp2jURru0PqUITkZaf3UWVzjXUN2VpQWfPFJ/45rIrF0swyv3ZU=',
#    'x-amz-request-id': 'HWMZ8S8EK7WK90R7',
#    'date': 'Sun, 15 Aug 2021 03:57:38 GMT',
#    'x-amz-version-id': 'nUFViJEvFLikLaX9SO_51gcT45.Sx9eZ',
#    'x-amz-delete-marker': 'true',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'DeleteMarker': True,
#  'VersionId': 'nUFViJEvFLikLaX9SO_51gcT45.Sx9eZ'}

# %%
#Delete a Bucket

#for delete a Bucket we should empty that before delete

# %%
# How to empty a Bucket and then delete that Bucket

# %%
'''
Syntax:-

<Handler Name> = s3.Bucket('< bucket name >')

for key in <Handler Name>.objects.all():
    key.delete()      #empty the Bucket

#then delete that Bucket
    
<Handler Name>.delete()
'''
# Out:
# "\n<Handler Name> = s3.Bucket('< bucket name >')\n\nfor key in <Handler Name>.objects.all():\n    key.delete()      #empty the Bucket\n\n#then delete that Bucket\n    \n<Handler Name>.delete()\n"

# %%
bct=s3.Bucket('som-aws-bucket-2')

# %%
bct.delete()
# Out:
# {'ResponseMetadata': {'RequestId': 'RDY8CQ4X6274N28V',
#   'HostId': 'viMSrFs7iK2d/ovaxDtpUCup00mUo62XjJ3ark4loojjWwJCAdxvHSF5XXSQM/04rmVff0FbhbA=',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'x-amz-id-2': 'viMSrFs7iK2d/ovaxDtpUCup00mUo62XjJ3ark4loojjWwJCAdxvHSF5XXSQM/04rmVff0FbhbA=',
#    'x-amz-request-id': 'RDY8CQ4X6274N28V',
#    'date': 'Sun, 15 Aug 2021 04:09:04 GMT',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 1}}

# %%
#upload a file into s3 bucket

# %%
s3.meta.client.upload_file(r'C:\Users\soman\Downloads\Train.csv','som-aws-bucket-1','Train.csv')
