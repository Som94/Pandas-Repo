# %%
import boto3
import pandas as pd

# %% [markdown]
# Create Resourse of s3 Bucket

# %%
s3=boto3.resource('s3')

# %% [markdown]
# Create Client for s3 Bucket

# %%
s3_client=boto3.client('s3')

# %% [markdown]
# Accessiing a Object from s3 Bucket through client

# %%
objc=s3_client.get_object(Bucket='som-aws-bucket-1',Key='Train.csv')

# %% [markdown]
# To read that object file body we should 'Body'

# %%
Train_data=pd.read_csv(objc['Body'])

# %% [markdown]
# print data

# %%
Train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# Create file same as train by copying file for keep Our original File

# %%
Outlet_data1=Train_data

# %%
Outlet_data1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
gp1=Outlet_data1.groupby('Outlet_Identifier')

# %%
list_outlet_identifier={}

for data,value in gp1:
    list_outlet_identifier[data]=value
#     print(data)
#     print(value)
#     #print(gp1.get_group(data[0])['Outlet_Size'].mode()[0])
#     for k in gp1.get_group(data[0])['Outlet_Size']:
#         print(k.fillna(gp1.get_group(data[0])['Outlet_Size'].mode()[0]), inplace=Ture)

# %%
print(list_outlet_identifier)
# Out:
# {'OUT010':      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 28             FDE51        5.925          Regular         0.161467
# 30             FDV38       19.250          Low Fat         0.170349
# 45             FDM39        6.420               LF         0.089499
# 65             FDC46       17.700               LF         0.195068
# ...              ...          ...              ...              ...
# 8400           NCE07        8.180          Low Fat         0.021977
# 8432           FDI16       14.000          Regular         0.227261
# 8473           DRI47       14.700          Low Fat         0.035016
# 8486           FDR20       20.000          Regular         0.000000
# 8509           FDG45        8.100          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
import sqlalchemy

# %%
name='root'            # Your MySQL User name
password='root'        # Your Password
database_name='test'   # your Database Name

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://' + name + ':' + password + '@localhost:3306/' + database_name)

# %%
for k,v in list_outlet_identifier.items():
    v.to_sql(name=k,con=engine,if_exists='append',index=False)
# Out:
# C:\Users\soman\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'OUT010' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\soman\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'OUT013' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# C:\Users\soman\anaconda3\lib\site-packages\pandas\io\sql.py:1685: UserWarning: The provided table name 'OUT017' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)
# ...

# %%
all_user_details = pd.read_sql_query("update OUT049 set Item_Weight=90 where Item_Identifier='FDA15' ;", engine)
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-182-5e97464f75ea> in <module>
# ----> 1 all_user_details = pd.read_sql_query("update OUT049 set Item_Weight=90 where Item_Identifier='FDA15' ;", engine)
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1591             )
#    1592         else:
# -> 1593             data = result.fetchall()
#    1594             frame = _wrap_result(
#    1595                 data,
#
# ...

# %%
all_user=all_user_details.head(5)

# %%
all_user

# %%
all_user_details = pd.read_sql_query("update OUT049 set Item_Weight=90 where Item_Identifier=FDA15 ;", engine)

# %%
all_user.iloc[:,0]

# %%
l=[]
for i in all_user.iloc[:,0]:
    print(i)
    l.append(i)

# %%
print(l)
if 'FDA15' in l:
    print("Y")
else:
    print("n")

# %%
l=[1,3,4,5,6,7]
if 3 in l:
    print("y")
else:
    print("no")

# %%
l=['FDA15', 'FDN15', 'FDY07', 'FDX32', 'FDP49']

# %%
df3=pd.DataFrame([l],columns=['u','b','c','d','e'])

# %%
df3

# %%
user_detail=pd.read_sql_query("select password from User_Details where User_id=7978840210;", engine)

# %%
user_detail
# Out:
#    password
# 0    456545

# %%
type(str(user_detail['password'][0]))
# Out:
# str

# %%
user_id_n_pass=user_detail.groupby(['User_id','Password'])

# %%
for i,j in user_id_n_pass:
    print(i)
# Out:
# ('7978840210', 401162)

# %%
tpl=[('7978840210', 401162),('Som', 4012),('9658755334', 5551)]

# %%
tpl
# Out:
# [('7978840210', 401162), ('Som', 4012), ('9658755334', 5551)]

# %%
d=input("Enter user id :")
pw=input("Enter password :")
# Out:
# Enter user id :
# Enter password :

# %%
id=input("Enter user id :")
# pw=int(input("Enter password :"))

# try:
#     psw=pd.read_sql_query("select password from User_Details where User_id=d;", engine)
# except:
#     print("User id does not exist..")
# else:
#     if pw==psw:
#         print("True")
#     else:
#         print("False")
pd.read_sql_query("update user_details set password='456545' where user_id={};".format(id), engine)
print("Updated sucessfully")
# Out:
# Enter user id :7978840210
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-20-7e042e27cb92> in <module>
#      11 #     else:
#      12 #         print("False")
# ---> 13 pd.read_sql_query("update user_details set password='456545' where user_id={};".format(id), engine)
#      14 print("Updated sucessfully")
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1591             )
#    1592         else:
# -> 1593             data = result.fetchall()
# ...
