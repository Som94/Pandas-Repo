# %%
import pandas as pd

# %%
df=pd.read_csv(r'E:\Aroha Tech\Pandas Session\Data_Outlet.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# find 2nd highest Item_Outlet_Sales in each Outlet_type

# %%
oltr=df.groupby('Outlet_Type').max('Item_Outlet_Sales')
oltr['Item_Outlet_Sales']
# Out:
# Outlet_Type
# Grocery Store         1775.6886
# Supermarket Type1    10256.6490
# Supermarket Type2     6768.5228
# Supermarket Type3    13086.9648
# Name: Item_Outlet_Sales, dtype: float64

# %%
acd=df.groupby('Outlet_Type').apply(lambda x : x[x['Item_Outlet_Sales']<x['Item_Outlet_Sales'].max()].max())

# %%
acd
# Out:
# Outlet_Type
# Grocery Store      Item_Identifier                          NCZ54
#                    Item_Weight                              21.35
#                    Item_Fat_Content                           reg
#                    Item_Visibility                       0.328391
#                    Item_Type                        Starchy Foods
#                    Item_MRP                              266.6884
#                    Outlet_Identifier                       OUT019
#                    Outlet_Establishment_Year                 1998
#                    Outlet_Location_Type                    Tier 3
#                    Outlet_Type                      Grocery Store
#                    Item_Outlet_Sales                    1575.2828
# Supermarket Type1  Item_Identifier                          NCZ54
#                    Item_Weight                              21.35
#                    Item_Fat_Content                           reg
# ...

# %% [markdown]
# Fill nan value of Item_visibility  with average value of each item_type in apropriate position

# %%
avg_val=df.groupby('Item_Type')

# %%
mean('Item_Visibility')
# Out:
#                        Item_Weight  Item_Visibility    Item_MRP  \
# Item_Type
# Baking Goods             12.277108         0.069169  126.380766
# Breads                   11.346936         0.066255  140.952669
# Breakfast                12.768202         0.085723  141.788151
# Canned                   12.305705         0.068129  139.763832
# Dairy                    13.426069         0.072427  148.499208
# Frozen Foods             12.867061         0.065645  138.503366
# Fruits and Vegetables    13.224769         0.068513  144.581235
# Hard Drinks              11.400328         0.064943  137.077928
# Health and Hygiene       13.142314         0.055216  130.818921
# Household                13.384736         0.061322  149.424753
# Meat                     12.817344         0.062284  139.882032
# Others                   13.853285         0.060241  132.851430
# Seafood                  12.552843         0.074976  141.841719
# ...

# %% [markdown]
# Based on Outlet_Identifier find how many item_types are there in a perticular Outlet_Identifier

# %%
oti=df['Outlet_Identifier'].value_counts()

# %%
oti
# Out:
# OUT027    935
# OUT013    932
# OUT046    930
# OUT035    930
# OUT049    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
for i in oti.index:
    print(i)
    ot=df['Outlet_Identifier']==i
    print(df.loc[ot]['Item_Type'].value_counts())
# Out:
# OUT027
# Fruits and Vegetables    140
# Snack Foods              137
# Household                 99
# Frozen Foods              89
# Canned                    72
# Baking Goods              69
# Dairy                     67
# Health and Hygiene        60
# Meat                      56
# Soft Drinks               45
# Breads                    31
# Hard Drinks               23
# Others                    15
# Starchy Foods             14
# Breakfast                 11
# Seafood                    7
# Name: Item_Type, dtype: int64
# OUT013
# Fruits and Vegetables    142
# Snack Foods              125
# Household                103
# Frozen Foods              92
# Dairy                     80
# Baking Goods              73
# Canned                    65
# Health and Hygiene        61
# Soft Drinks               49
# Meat                      41
# Breads                    25
# Hard Drinks               23
# Starchy Foods             19
# Others                    16
# ...

# %% [markdown]
# Or,

# %%
gp=df.groupby('Outlet_Identifier')

# %%
value=gp['Item_Type'].value_counts()
value
# Out:
# Outlet_Identifier  Item_Type
# OUT010             Fruits and Vegetables    79
#                    Snack Foods              71
#                    Household                67
#                    Frozen Foods             54
#                    Dairy                    43
#                                             ..
# OUT049             Breads                   25
#                    Others                   17
#                    Starchy Foods            17
#                    Breakfast                13
#                    Seafood                   7
# Name: Item_Type, Length: 160, dtype: int64

# %% [markdown]
# Findout maximum repeated Outlety_type in each outlet_location_type

# %%
olt=df.groupby('Outlet_Location_Type')

# %%
ot_value=olt['Outlet_Type'].value_counts()

# %%
ot_value
# Out:
# Outlet_Location_Type  Outlet_Type
# Tier 1                Supermarket Type1    1860
#                       Grocery Store         528
# Tier 2                Supermarket Type1    2785
# Tier 3                Supermarket Type3     935
#                       Supermarket Type1     932
#                       Supermarket Type2     928
#                       Grocery Store         555
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# Which Outlet_type having highest sales in a perticular year

# %%
group_by_outlet_type=df.groupby('Outlet_Type')

# %%
item_olt_sales=group_by_outlet_type['Item_Outlet_Sales']

# %%
item_olt_sales

# %%
groupby_OEY=df.groupby('Outlet_Establishment_Year')

# %%
a=groupby_OEY['Outlet_Type']
